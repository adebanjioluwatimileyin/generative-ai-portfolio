# %%
import os
import openai

# %%
# !pip show openai

# %%
from getpass import getpass
api_key=getpass("OpenAI API Key: ")

# %%
import pandas as pd

# %%
client = openai.OpenAI(api_key=api_key)

# %%
pd.DataFrame([model.model_dump() for model in client.models.list().data])
# Out:
#                          id     created object         owned_by
# 0                gpt-4-0613  1686588896  model           openai
# 1                     gpt-4  1687882411  model           openai
# 2             gpt-3.5-turbo  1677610602  model           openai
# 3              gpt-5.4-mini  1773451123  model           system
# 4                   gpt-5.4  1772691852  model           system
# ..                      ...         ...    ...              ...
# 115  gpt-5.4-pro-2026-03-05  1772659657  model           system
# 116       gpt-3.5-turbo-16k  1683758102  model  openai-internal
# 117                   tts-1  1681940951  model  openai-internal
# 118               whisper-1  1677532384  model  openai-internal
# 119  text-embedding-ada-002  1671217299  model  openai-internal
#
# [120 rows x 4 columns]

# %% [markdown]
# # ChatCompletion API and Completion API
#
# - Completion API: Hooks you up with text completions from a single prompt.
#
# - Chat Completion API: Nails it in the chat game, keeping the conversational flow intact

# %% [markdown]
# # ChatCompletion API

# %%
prompt = "Hello, How are you?"

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ]
)

print(response)
# Out:
# ChatCompletion(id='chatcmpl-DVScnim0Ol7GbH96nv8XM9rn4vUmy', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Hello! I'm just a computer program, so I don't have feelings, but I'm here to help you. How can I assist you today?", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1776390573, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=31, prompt_tokens=23, total_tokens=54, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
prompt = "Hello, How are you?"

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ]
)

print(response.choices[0].message.content)
# Out:
# Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?

# %%
# ChatCompletion API 

prompt1 = "Hello How are you?"
prompt2 = "I am 25 years old & I am a Programmer"
prompt3 = "Tell me about me"

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt1},
        {"role": "user", "content": prompt2},
        {"role": "user", "content": prompt3},
    ]
)

print(response.choices[0].message.content)
# Out:
# Based on the information you provided, you are 25 years old and work as a programmer. This suggests that you have a background in computer science or a related field, and you likely have skills in software development and coding. As a programmer, you likely work with different programming languages and tools to create, maintain, or troubleshoot software applications or systems. Your job may involve problem-solving, critical thinking, and creativity to write efficient code and develop solutions to meet specific requirements. Overall, being a programmer at a relatively young age indicates a strong interest and proficiency in technology and programming languages.

# %%
prompt = "What is Python?"

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    max_tokens=25
)

print(response.choices[0].message.content)
# Out:
# Python is a popular high-level programming language known for its simplicity and readability. It supports multiple programming paradigms and is widely

# %%
prompt = "What is Python?"

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    max_tokens=25
)

print(response)
# Out:
# ChatCompletion(id='chatcmpl-DVSctIwHvu2n9WHtcMOsRErMhIy8H', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='Python is a high-level, interpreted programming language known for its simplicity and readability. It supports multiple programming paradigms, including', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1776390579, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=25, prompt_tokens=21, total_tokens=46, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
# ChatCompletion API 

prompt = "What is Python?"

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.6
)

print(response.choices[0].message.content)
# Out:
# Python is a high-level, interpreted programming language known for its simplicity and readability. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python is widely used for web development, data analysis, artificial intelligence, scientific computing, and many other applications. It has a large standard library and a vibrant community that contributes to its popularity and versatility.

# %%
# ChatCompletion API 

prompt = "What is Python?"

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.6,
    n=3
)

print(response)
# Out:
# ChatCompletion(id='chatcmpl-DVScw94HQn9qmS07Nl2ZrvrvQgLUE', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Python is a high-level, interpreted programming language known for its simplicity and readability. It is widely used for web development, data analysis, artificial intelligence, scientific computing, and more. Python supports multiple programming paradigms, including object-oriented, imperative, and functional programming. It has a large standard library and a vibrant community that contributes to its extensive ecosystem of libraries and frameworks.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None)), Choice(finish_reason='stop', index=1, logprobs=None, message=ChatCompletionMessage(content='Python is a high-level programming language known for its simplicity and readability. It is widely used for various applications such as web development, data analysis, artificial intelligence, scientific computing, and more. Python supports multiple programming paradigms and has a large standard library that provides tools and modules for various tasks.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None)), Choice(finish_reason='stop', index=2, logprobs=None, message=ChatCompletionMessage(content='Python is a high-level, versatile programming language known for its simplicity and readability. It is widely used for web development, data analysis, artificial intelligence, scientific computing, and more. Python supports multiple programming paradigms and has a vast standard library, making it a popular choice for both beginners and experienced programmers.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1776390582, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=197, prompt_tokens=21, total_tokens=218, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
# ChatCompletion API 

prompt = "Give me the sentiment of this sentence: This Movie is Amazing!"

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.6,
)

print(response.choices[0].message.content)
# Out:
# The sentiment of the sentence "This Movie is Amazing!" is positive.

# %%
# ChatCompletion API 

prompt = "Give me hindi transilation of this sentence: This Movie is Amazing!"

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.6,
)

print(response.choices[0].message.content)
# Out:
# यह फ़िल्म शानदार है!

# %%
# ChatCompletion API 

prompt = "Detect the language of this sentence: This Movie is Amazing!"

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.6,
)

print(response.choices[0].message.content)
# Out:
# The sentence "This Movie is Amazing!" is in English.

# %%
# ChatCompletion API 

prompt = "Give me a Python code to add 2 numbers"

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.6,
)

print(response.choices[0].message.content)
# Out:
# Certainly! Here is a simple Python code to add two numbers:
#
# ```python
# num1 = 5
# num2 = 10
#
# sum = num1 + num2
#
# print("The sum of", num1, "and", num2, "is:", sum)
# ```
#
# You can replace the values of `num1` and `num2` with any numbers you want to add. When you run this code, it will calculate the sum of the two numbers and print the result.

# %% [markdown]
# # Completion API

# %%
prompt = "What is Python"
response = client.completions.create(
    model="babbage-002",
    prompt=prompt
)
print(response)
# Out:
# Completion(id='cmpl-DVSd21dsK9axZxlUMSV0UhaZG1TZP', choices=[CompletionChoice(finish_reason='length', index=0, logprobs=None, text=' real coding for essential metaprogramming? \n- Help identify this worm-like')], created=1776390588, model='babbage:2023-07-21-v2', object='text_completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=16, prompt_tokens=3, total_tokens=19, completion_tokens_details=None, prompt_tokens_details=None))

# %%
print(response.choices[0].text)
# Out:
#  real coding for essential metaprogramming?
# - Help identify this worm-like
